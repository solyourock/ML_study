# %%
# 코랩에 mecab 설치
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# %cd Mecab-ko-for-Google-Colab
# !bash install_mecab-ko_on_colab190912.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 109 (delta 7), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (109/109), 1.27 MiB | 4.64 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/Mecab-ko-for-Google-Colab
# Installing konlpy.....
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 35.6 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.5)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 68.5 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.3.0 konlpy-0.6.0
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# Downloading mecab-0.996-ko-0.9.2.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-04-11 07:30:36--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::3403:4be7, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=bbN6laws5H%2B9B3tZYzF9hPvraEE%3D&Expires=1649663172&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [following]
# --2022-04-11 07:30:36--  https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=bbN6laws5H%2B9B3tZYzF9hPvraEE%3D&Expires=1649663172&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.134.121
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.134.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1414979 (1.3M) [application/x-tar]
# Saving to: ‘mecab-0.996-ko-0.9.2.tar.gz’
#
# mecab-0.996-ko-0.9. 100%[===================>]   1.35M  2.65MB/s    in 0.5s
#
# 2022-04-11 07:30:37 (2.65 MB/s) - ‘mecab-0.996-ko-0.9.2.tar.gz’ saved [1414979/1414979]
#
# Done
# Unpacking mecab-0.996-ko-0.9.2.tar.gz.......
# Done
# Change Directory to mecab-0.996-ko-0.9.2.......
# installing mecab-0.996-ko-0.9.2.tar.gz........
# configure
# make
# make check
# make install
# ldconfig
# Done
# Change Directory to /content
# Downloading mecab-ko-dic-2.1.1-20180720.tar.gz.......
# from https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# --2022-04-11 07:31:53--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::3403:4be7, 2406:da00:ff00::6b17:d1f5, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=PvBePlJkQm76257H9LHfrLD644Y%3D&Expires=1649663239&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None [following]
# --2022-04-11 07:31:54--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?Signature=PvBePlJkQm76257H9LHfrLD644Y%3D&Expires=1649663239&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=tzyxc1TtnZU_zEuaaQDGN4F76hPDpyFq&response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.217.101.180
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.217.101.180|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  25.6MB/s    in 1.9s
#
# 2022-04-11 07:31:56 (25.6 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# Done
# Unpacking  mecab-ko-dic-2.1.1-20180720.tar.gz.......
# Done
# Change Directory to mecab-ko-dic-2.1.1-20180720
# Done
# installing........
# configure
# make
# make install
# apt-get update
# apt-get upgrade
# apt install curl
# apt install git
# bash <(curl -s https://raw.githubusercontent.com/konlpy/konlpy/master/scripts/mecab.sh)
# Done
# Successfully Installed
# Now you can use Mecab
# from konlpy.tag import Mecab
# mecab = Mecab()
# 사용자 사전 추가 방법 : https://bit.ly/3k0ZH53
# NameError: name 'Tagger' is not defined 오류 발생 시 런타임을 재실행 해주세요
# 블로그에 해결 방법을 남겨주신 tana님 감사합니다.

# %%
import os
import re
import platform

import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from PIL import Image
from wordcloud import WordCloud, STOPWORDS

from tqdm import tqdm
from collections import Counter
from konlpy.tag import Kkma, Komoran, Okt, Mecab
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# PROJECT_ROOT_DIR = "."
# IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
# os.makedirs(IMAGES_PATH, exist_ok=True)

# def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
#     path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
#     print("그림 저장:", fig_id)
#     if tight_layout:
#         plt.tight_layout()
#     plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# def Fontmanager():

#     plt.rcParams['axes.unicode_minus'] = False

#     if platform.system() == 'Windows':
#         path = "c:/Windows/Fonts/malgun.ttf"
#         font_name = font_manager.FontProperties(fname=path).get_name()
#         rc('font', family=font_name)
#     elif platform.system() == 'Darwin':
#         path = '/Library/Fonts/Arial Unicode.ttf'
#         font_name = font_manager.FontProperties(fname=path).get_name()
#         rc('font', family='AppleGothic')
#     elif platform.system() == 'Linux':
#         path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
#         font_name = font_manager.FontProperties(fname=path).get_name()
#         rc('font', family='NanumBarunGothic')
#     else:
#         print('Unknown system... sorry~~~~~~')
#     print(f"해당 pc의 운영 체제는 {platform.system()}이며 {font_name}로 설정되었습니다")  
#     return path

# %%
# path = Fontmanager()

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-15d66808-e847-4952-b004-a033fce82e8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15d66808-e847-4952-b004-a033fce82e8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving women_policy.csv to women_policy.csv
# {'women_policy.csv': b'\xef\xbb\xbfdatetime,id,text,username\n2022-02-10 01:57:58+00:00,1491592245379678208,\xeb\x8c\x80\xed\x86\xb5\xeb\xa0\xb9\xec\x9d\x84 \xeb\xb3\xb8 \xec\x9d\xb4\xeb\x9e\x98 \xea\xb0\x80\xec\x9e\xa5 \xea\xb0\x95\xed\x95\x9c \xeb\xb0\x9c\xec\x96\xb8\xec\x9d\xb4 \xeb\x82\x98\xec\x99\x94\xec\x9d\x8c\xe3\x85\x9c\xe3\x85\x9c \xea\xb0\x81\xed\x95\x98 \xec\xb6\xa9\xec\x84\xb1\xec\xb6\xa9\xec\x84\xb1\xec\xb6\xa9\xec\x84\xb1 \xeb\xaf\xbc\xec\xa3\xbc\xeb\x8b\xb9\xec\x9d\x98 \xec\x97\xac\xec\x84\xb1\xec\xa0\x95\xec\xb1\x85 \xeb\x85\xb8\xeb\x8f\x99\xec\xa0\x95\xec\xb1\x85 \xed\x99\x98\xea\xb2\xbd\xec\xa0\x95\xec\xb1\x85  \xec\x97\xb4\xec\x8b\xac\xed\x9e\x88 \xed\x99\x8d\xeb\xb3\xb4\xed\x95\x98\xea\xb3\xa0 \xeb\x98\x90 \xec\x98\x81\xec\x97\x85\xed\x95\x98\xea\xb2\xa0\xec\x8a\xb4\xeb\x8b\xa4 \xeb\xac\xb8\xec\x9e\xac\xec\x9d\xb8 \xeb\x84\x88\xeb\xac\xb4\xeb\x84\x88\xeb\xac\xb4 \xec\x82\xac\xeb\x9e\x91\xed\x95\x98\xea\xb3\xa0 \xec\xa1\xb4\xea\xb2\xbd\xed\x95\xa9\xeb\x8b\x88\xeb\x8b\xa4\xe3\x85\x9c\xe3\x85\x9c\xe3\x85\x9c,cue3u\n2022-02-10 03:03:04+00:00,1491608626779557890,"\xeb\xac\xb8\xeb\x8c\x80\xed\x86\xb5\xeb\xa0\xb9\xec\x9d\x80 \xec\xa7\x80\xec\xa7\x80\xed\x95\x98\xea\xb3\xa0 \xec\x9d\xb4\xec\x9e\xac\xeb\xaa\x85\xec\x9d\x80 \xec\xa1\xb4\xeb\x82\x98 \xec\x8b\xab\xec\x96\xb4\xec\x84\x9c \xeb\xbd\x91\xec\x9d\x84 \xec\x82\xac\xeb\x9e\x8c \xec\x97\x86\xec\x96\xb4\xea\xb0\x80\xec\xa7\x80\xea\xb3\xa0 \xea\xb4\xb4\xeb\xa1\xad\xeb\x84\xa4 \xec\x96\xb4\xec\xa9\x8c\xeb\x84\xa4 \xed\x95\x98\xeb\x8a\x94 \xea\xb1\xb0 \xec\xa7\x84\xec\xa7\x9c \xec\x9b\x83\xea\xb9\x80\n\xec\x97\xac\xec\x84\xb1\xec\xa0\x95\xec\xb1\x85 \xea\xb0\x80\xec\xa7\x80\xea\xb3\xa0 \xec\x9e\x90\xeb\xb9\xa0\xec\xa7\x84 \xea\xb1\xb0\xeb\xa9\xb4 \xec\xa0\x9c\xeb\x8c\x80\xeb\xa1\x9c \xec\x9d\xbd\xea\xb3\xa0 \xec\x99\x94\xec\x9c\xbc\xeb\xa9\xb4 \xec\xa2\x8b\xea\xb2\xa0\xec\x9d\x8c\n\xea\xb7\xbc\xeb\x8d\xb0 \xec\xa7\x80\xeb\x82\x9c \xeb\x8c\x80\xec\x84\xa0 \xea\xb4\x80\xeb\xa0\xa8\xec\x9c\xbc\xeb\xa1\x9c \xec\x9d\xb4\xec\x9e\xac\xeb\xaa\x85\xec\x9d\xb4 \xec\x8b\xab\xec\x96\xb4\xec\x84\x9c \xeb\xaa\xbb \xeb\xbd\x91\xea\xb2\xa0\xeb\x8b\xa4\xea\xb3\xa0 \xed\x95\x98\xeb\x8a\x94 \xec\x82\xac\xeb\x9e\x8c\xeb\x93\xa4\xec\x9d\x80 \xeb\x84\x88\xeb\xac\xb4 \xed\x98\xbc\xec\x9e\x90\xec\x84\x9c \xea\xb3\xbc\xeb\xaa\xb0\xec\x9e\x85\xed\x95\x98\xeb\xa9\xb4\xec\x84\x9c \xec\x82\xac\xeb\x8a\x94\xea\xb1\xb0 \xec\x95\x84\xeb\x8b\x8c\xea\xb0\x80?",Unkn0wnG0ldf1sh\n2022-02-10 03:06:08+00:00,1491609398858248192,"\xec\x96\xb8\xec\xa0\x9c\xeb\x8a\x94 \xed\x94\xbc\xed\x95\xb4\xec\x9e\x90 \xec\x96\xb8\xea\xb8\x89\xea\xb3\xbc \xec\x82\xac\xea\xb3\xbc\xeb\xa5\xbc \xec\x95\x88 \xed\x96\x88\xec\x9c\xbc\xeb\x8b\x88 \xeb\xaf\xbc\xec\xa3\xbc\xeb\x8b\xb9\xec\x97\x90 \xeb\x8f\x8c\xec\x95\x84\xec\x84\x9c\xea\xb2\xa0\xeb\x8b\xa4 \xed\x95\x98\xeb\x8d\x94\xeb\x8b\x88, \xec\x9d\xb4\xec\xa0\x9c\xeb\x8a\x94 \xec\x82\xb4\xec\x9d\xb8\xec\x9e\x90\xea\xb0\x80 \xeb\x82\xb4\xec\x84\xb8\xec\x9a\xb0\xeb\x8a\x94 \xed\x97\x88\xec\x9a\xb8\xeb\xbf\x90\xec\x9d\xb8 \xec\x97\xac\xec\x84\xb1\xec\xa0\x95\xec\xb1\x85\xec\x9d\x84 \xec\x98\xac\xeb\xa0\xa4\xec\xb9\x98\xeb\x84\xa4. \xec\x9d\xb4\xec\xaf\xa4\xec\x9d\xb4\xeb\xa9\xb4 \xeb\xb3\xb4\xed\x99\x95\xec\xb0\xa2 \xeb\xb0\x9c\xec\x96\xb8\xeb\x8f\x84 \xec\xa1\xb0\xec\x9e\x91\xec\x9d\xb4\xeb\x9d\xbc\xea\xb3\xa0 \xed\x95\x98\xea\xb2\xa0\xeb\x8a\x94\xeb\x8d\xb0. \xea\xb7\xb8\xeb\x83\xa5 \xec\x9b\x90\xeb\x9e\x98 \xec\xb6\x94\xec\xa2\x85\xec\x9e\x90\xec\x98\x80\xeb\x8d\x98 \xea\xb1\xb0 \xec\x95\x84\xeb\x8b\x8c\xea\xb0\x80 \xec\x8b\xb6\xea\xb3\xa0~",remmremmr\n2022-02-10 05:03:53+00:00,1491639032224583681,\xec\x8b\xa0\xeb\x82\xa8\xec\x84\xb1\xec\x97\xb0\xeb\x8c\x80 \xeb\xb0\xb0\xec\x9d\xb8\xea\xb7\x9c\xeb\x9e\x91 \xed\x95\x98\xeb\x93\xb1 \xeb\x8b\xa4\xeb\xa5\xbc\xeb\xb0\x94 \xec\x97\x86\xeb\x8a\x94 \xeb\x86\x88\xec\x9d\x84 \xeb\x8b\xb9 \xea\xb3\xb5\xec\x8b\x9d \xec\xa7\x81\xec\x9c\x84\xec\x97\x90 \xec\x95\x89\xed\x98\x80\xeb\x86\x93\xec\x9d\x80 \xec\x95\x88\xec\xb2\xa0\xec\x88\x98\ ...

# %%
women_policy = pd.read_csv('women_policy.csv')

# %%
women_policy = women_policy.drop_duplicates()

# %%
# 정규표현식 이용한 전처리
def clean(text):
    #\n 공백 제거
    text = re.sub('\n',' ',str(text))
    # URL 제거
    text = re.sub('https://[A-Za-z0-9./]*','',str(text))
    # 한글자 제거 (ex:ㅋㅋ, ㅜㅜ)
    text = re.sub('([ㄱ-ㅎㅏ-ㅣ])+', '', str(text))
    # 숫자 제거 (숫자 + 숫자만 제거, ex: 1인가족)
    text= re.sub('[0-9]{2}', '', str(text))
    # @알파벳 제거 
    text = re.sub('@[A-Za-z0-9./]*','',str(text))
    return str(text)

# %%
women_policy['text'] = women_policy['text'].apply(lambda x : clean(x))

# %%
mecab = Mecab()

# %%
def preprocessing_mecab(sentence):
    #### Tokenize
    morphs = mecab.pos(sentence)
    
    JOSA = ["JKS", "JKC", "JKG", "JKO", "JKB", "JKV", "JKQ", "JX", "JC"] # 조사
    SIGN = ["SF", "SE", "SSO", "SSC", "SC", "SY"] # 문장 부호
    TERMINATION = ["EP", "EF", "EC", "ETN", "ETM"] # 어미
    SUPPORT_VERB = ["VX"] # 보조 용언
    NUMBER = ["SN"]
    
    # Remove JOSA, EOMI, etc
    morphs[:] = (morph for morph in morphs if morph[1] not in JOSA+SIGN+TERMINATION+SUPPORT_VERB)
        
    # Remove length-1 words  
    morphs[:] = (morph for morph in morphs if not (len(morph[0]) == 1))
    
    # Remove Numbers
    morphs[:] = (morph for morph in morphs if morph[1] not in NUMBER)
   
    # Result pop-up
    result = []
    for morph in morphs:
        result.append(morph[0])
        
    return result

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5643eede-e9c2-447f-892d-60c008a1a485" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5643eede-e9c2-447f-892d-60c008a1a485">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 한국어불용어100.txt to 한국어불용어100.txt
# {'한국어불용어100.txt': b'word\ttag\tcount\n\xec\x9d\xb4\tVCP\t0.018279601\r\n\xec\x9e\x88\tVA\t0.011699048\r\n\xed\x95\x98\tVV\t0.009773658\r\n\xea\xb2\x83\tNNB\t0.00973315\r\n\xeb\x93\xa4\tXSN\t0.00689824\r\n\xea\xb7\xb8\tMM\t0.005327252\r\n\xeb\x90\x98\tVV\t0.00361335\r\n\xec\x88\x98\tNNB\t0.003473622\r\n\xec\x9d\xb4\tNP\t0.003361203\r\n\xeb\xb3\xb4\tVX\t0.003310379\r\n\xec\x95\x8a\tVX\t0.0029757\r\n\xec\x97\x86\tVA\t0.002920476\r\n\xeb\x82\x98\tNP\t0.002690479\r\n\xec\xa3\xbc\tVV\t0.001884579\r\n\xec\x95\x84\xeb\x8b\x88\tVCN\t0.001870774\r\n\xeb\x93\xb1\tNNB\t0.001822074\r\n\xea\xb0\x99\tVA\t0.001724522\r\n\xeb\x95\x8c\tNNG\t0.001685684\r\n\xeb\x85\x84\tNNB\t0.001647755\r\n\xea\xb0\x80\tVV\t0.001618626\r\n\xed\x95\x9c\tMM\t0.001584036\r\n\xec\xa7\x80\tVX\t0.001537763\r\n\xeb\x8c\x80\xed\x95\x98\tVV\t0.00150378\r\n\xec\x98\xa4\tVV\t0.001490884\r\n\xeb\xa7\x90\tNNG\t0.001321876\r\n\xec\x9d\xbc\tNNG\t0.001239799\r\n\xea\xb7\xb8\xeb\xa0\x87\tVA\t0.001232062\r\n\xec\x9c\x84\xed\x95\x98\tVV\t0.001170618\r\n\xeb\x95\x8c\xeb\xac\xb8\tNNB\t0.001146647\r\n\xea\xb7\xb8\xea\xb2\x83\tNP\t0.001099161\r\n\xeb\x91\x90\tVV\t0.001063053\r\n\xeb\xa7\x90\xed\x95\x98\tVV\t0.001030587\r\n\xec\x95\x8c\tVV\t0.000995693\r\n\xea\xb7\xb8\xeb\x9f\xac\xeb\x82\x98\tMAJ\t0.000978246\r\n\xeb\xb0\x9b\tVV\t0.000924084\r\n\xeb\xaa\xbb\xed\x95\x98\tVX\t0.000904665\r\n\xec\x9d\xbc\tNNB\t0.000880239\r\n\xea\xb7\xb8\xeb\x9f\xb0\tMM\t0.000879481\r\n\xeb\x98\x90\tMAG\t0.000870985\r\n\xeb\x8d\x94\tMAG\t0.000801652\r\n\xeb\xa7\x8e\tVA\t0.000789211\r\n\xea\xb7\xb8\xeb\xa6\xac\xea\xb3\xa0\tMAJ\t0.000779653\r\n\xec\xa2\x8b\tVA\t0.000763723\r\n\xed\x81\xac\tVA\t0.000758565\r\n\xeb\x94\xb0\xeb\xa5\xb4\tVV\t0.000738084\r\n\xec\xa4\x91\tNNB\t0.000733229\r\n\xeb\x82\x98\xec\x98\xa4\tVV\t0.000725188\r\n\xea\xb0\x80\xec\xa7\x80\tVV\t0.000720485\r\n\xec\x94\xa8\tNNB\t0.000710169\r\n\xec\x8b\x9c\xed\x82\xa4\tXSV\t0.000707893\r\n\xeb\xa7\x8c\xeb\x93\xa4\tVV\t0.000703797\r\n\xec\xa7\x80\xea\xb8\x88\tNNG\t0.000699701\r\n\xec\x83\x9d\xea\xb0\x81\xed\x95\x98\tVV\t0.000694846\r\n\xea\xb7\xb8\xeb\x9f\xac\tVV\t0.000692418\r\n\xec\x86\x8d\tNNG\t0.00068544\r\n\xed\x95\x98\xeb\x82\x98\tNR\t0.000655097\r\n\xec\xa7\x91\tNNG\t0.000648573\r\n\xec\x82\xb4\tVV\t0.000648422\r\n\xeb\xaa\xa8\xeb\xa5\xb4\tVV\t0.000645084\r\n\xec\xa0\x81\tXSN\t0.000643112\r\n\xec\x9b\x94\tNNB\t0.000639319\r\n\xeb\x8d\xb0\tNNB\t0.000636436\r\n\xec\x9e\x90\xec\x8b\xa0\tNNG\t0.000632188\r\n\xec\x95\x88\tMAG\t0.000625968\r\n\xec\x96\xb4\xeb\x96\xa4\tMM\t0.000623237\r\n\xeb\x82\xb4\tNP\t0.000622023\r\n\xeb\x82\xb4\tVV\t0.000614438\r\n\xea\xb2\xbd\xec\x9a\xb0\tNNG\t0.000613831\r\n\xeb\xaa\x85\tNNB\t0.00061019\r\n\xeb\x8b\xa4\xec\x8b\x9c\tMAG\t0.00055618\r\n\xec\x9d\xb4\xeb\x9f\xb0\tMM\t0.000550263\r\n\xec\x95\x9e\tNNG\t0.000548898\r\n\xeb\xb3\xb4\xec\x9d\xb4\tVV\t0.000542678\r\n\xeb\xb2\x88\tNNB\t0.000542526\r\n\xeb\x82\x98\tVX\t0.000538126\r\n\xeb\x8b\xa4\xeb\xa5\xb8\tMM\t0.000536306\r\n\xec\x96\xb4\xeb\x96\xbb\tVA\t0.000533423\r\n\xea\xb0\x9c\tNNB\t0.000530085\r\n\xec\xa0\x84\tNNG\t0.00052872\r\n\xeb\x93\xa4\tVV\t0.000514914\r\n\xec\x82\xac\xec\x8b\xa4\tNNG\t0.000511728\r\n\xec\x9d\xb4\xeb\xa0\x87\tVA\t0.000511576\r\n\xec\xa0\x90\tNNG\t0.000507935\r\n\xec\x8b\xb6\tVX\t0.000504749\r\n\xeb\xa7\x90\tVX\t0.000503991\r\n\xec\xa0\x95\xeb\x8f\x84\tNNG\t0.000496102\r\n\xec\xa2\x80\tMAG\t0.000492916\r\n\xec\x9b\x90\tNNB\t0.000492309\r\n\xec\x9e\x98\tMAG\t0.000491399\r\n\xed\x86\xb5\xed\x95\x98\tVV\t0.000486847\r\n\xec\x86\x8c\xeb\xa6\xac\tNNG\t0.000485633\r\n\xeb\x86\x93\tVX\t0.000482751\r\n'}

# %%
# stopwords list
stop_words = pd.read_csv('한국어불용어100.txt', sep = "\t", engine='python')
stop_words = list(stop_words["word"])

# %%
women_policy['tokenized'] = women_policy['text'].apply(lambda x: preprocessing_mecab(x))
women_policy['tokenized'] = women_policy['tokenized'].apply(lambda x: [item for item in x if item not in stop_words])

# %%
from tensorflow.keras.models import load_model

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b33baa76-1c58-4495-8d68-63cc9cc227a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b33baa76-1c58-4495-8d68-63cc9cc227a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
import re
import urllib.request

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f2c6215d7d0>)

# %%
train_data = pd.read_table('ratings_train.txt')
test_data = pd.read_table('ratings_test.txt')

# %%
train_data.drop_duplicates(subset=['document'], inplace=True)

# %%
train_data['document'] = train_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣]", "")
train_data['document'] = train_data['document'].str.replace('^ +', "")
train_data['document'].replace('',np.nan, inplace=True)

test_data['document'] = test_data['document'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣]", "")
test_data['document'] = test_data['document'].str.replace('^ +', "")
test_data['document'].replace('',np.nan, inplace=True)

# %%
# nan값 제거
train_data = train_data.dropna()
test_data = test_data.dropna()

# %%
# !pip install transformers

# %%
import transformers
from transformers import BertTokenizerFast
from transformers import TextClassificationPipeline
from transformers import TFBertForSequenceClassification

# %%
tokenizer = BertTokenizerFast.from_pretrained("klue/bert-base")
# Out:
# Downloading:   0%|          | 0.00/289 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/243k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/425 [00:00<?, ?B/s]

# %%
X_train_list = train_data['document'].tolist()
X_test_list = test_data['document'].tolist()
y_train = train_data['label'].tolist() # label 긍부정 표시
y_test = test_data['label'].tolist()

# %%
X_train = tokenizer(X_train_list, truncation=True, padding=True)
X_test = tokenizer(X_test_list, truncation=True, padding=True)

# %%
import tensorflow as tf
train_dataset = tf.data.Dataset.from_tensor_slices((dict(X_train), y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((dict(X_test), y_test))

# %%
from transformers import TFBertForSequenceClassification
from tensorflow.keras.callbacks import EarlyStopping

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)

# %%
model = TFBertForSequenceClassification.from_pretrained("klue/bert-base", num_labels=2, from_pt=True)
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])
# Out:
# Downloading:   0%|          | 0.00/424M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
callback_earlystop = EarlyStopping(
    monitor='val_accuracy',
    min_delta=0.001,
    patience=2)

model.fit(train_dataset.shuffle(10000).batch(32), epochs=5, batch_size=64,
          validation_data = val_dataset.shuffle(10000).batch(64),
          callbacks = [callback_earlystop])
# Out:
# Epoch 1/5
# 4544/4544 [==============================] - 1934s 426ms/step - loss: 0.2248 - accuracy: 0.8976 - val_loss: 0.3223 - val_accuracy: 0.8542
# Epoch 2/5
# 4544/4544 [==============================] - 1934s 426ms/step - loss: 0.1813 - accuracy: 0.9168 - val_loss: 0.3749 - val_accuracy: 0.8538
# Epoch 3/5
# 4544/4544 [==============================] - 1933s 425ms/step - loss: 0.1497 - accuracy: 0.9298 - val_loss: 0.4086 - val_accuracy: 0.8524

# %%
model.save_pretrained('nsmc_model/bert-base')
tokenizer.save_pretrained('nsmc_model/bert-base')
# Out:
# ('nsmc_model/bert-base/tokenizer_config.json',
#  'nsmc_model/bert-base/special_tokens_map.json',
#  'nsmc_model/bert-base/vocab.txt',
#  'nsmc_model/bert-base/added_tokens.json',
#  'nsmc_model/bert-base/tokenizer.json')

# %%
loaded_tokenizer = BertTokenizerFast.from_pretrained('nsmc_model/bert-base')
loaded_model = TFBertForSequenceClassification.from_pretrained('nsmc_model/bert-base')

text_classifier = TextClassificationPipeline(
    tokenizer=loaded_tokenizer,
    model=loaded_model,
    framework='tf',
    return_all_scores=False
)
# Out:
# Some layers from the model checkpoint at nsmc_model/bert-base were not used when initializing TFBertForSequenceClassification: ['dropout_37']
# - This IS expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertForSequenceClassification were initialized from the model checkpoint at nsmc_model/bert-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForSequenceClassification for predictions without further training.

# %%
women_policy['text']

# %%
text_classifier(women_policy['text'][0])[0]
# Out:
# {'label': 'LABEL_1', 'score': 0.9932625889778137}

# %%
c = []
for i in range(1127):
  b = text_classifier(women_policy['text'][i])[0]
  c.append(b)

# %%
c

# %%
c = pd.DataFrame(c)

# %%
women_policy['label'] = c['label']

# %%
women_policy['score'] = c['score']

# %%
women_policy.to_csv('women_policy_label.csv', index=False)

# %%
from google.colab import files
files.download('women_policy_label.csv')
